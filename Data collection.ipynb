# %% [markdown]
# # Data collection
#
# In this notebook, I'll use the **GitHub API** to extract various information from my user profile such as repositories, commits and more. I'll also save this data to **.csv** files so that I can draw insights.

# %% [markdown]
# ## Import libraries and defining constants
#
# I'll import various libraries needed for fetching the data.

# %%
import json
import requests
import numpy as np
import pandas as pd

import requests
from requests.auth import HTTPBasicAuth

# %% [markdown]
# I'll fetch the credentials from the json file and create an `authentication` variable.

# %%
credentials = json.loads(open('credentials.json').read())
authentication = HTTPBasicAuth(credentials['username'], credentials['password'])

# %% [markdown]
# ## User information
#
# I'll first extract the user information such as name and related URLs which would be useful ahead.

# %%
data = requests.get('https://api.github.com/users/' + credentials['username'],
                    auth = authentication)
data = data.json()
data
# Out:
# {'login': 'BandhaviC',
#  'id': 60414933,
#  'node_id': 'MDQ6VXNlcjYwNDE0OTMz',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/60414933?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/BandhaviC',
#  'html_url': 'https://github.com/BandhaviC',
#  'followers_url': 'https://api.github.com/users/BandhaviC/followers',
#  'following_url': 'https://api.github.com/users/BandhaviC/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/BandhaviC/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/BandhaviC/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/BandhaviC/subscriptions',
#  'organizations_url': 'https://api.github.com/users/BandhaviC/orgs',
#  'repos_url': 'https://api.github.com/users/BandhaviC/repos',
#  'events_url': 'https://api.github.com/users/BandhaviC/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/BandhaviC/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Bandhavi Chitturi',
#  'company': 'Data Analyst | Data Science | Masters in Management of Information Systems',
#  'blog': '',
#  'location': 'Smyrna, GA',
#  'email': None,
#  'hireable': None,
#  'bio': "I'm a passionate Data enthusiast! I have experience as a Data Analyst. I like to bring insights from data that helps in predictions and recommendation systems.",
#  'twitter_username': None,
#  'public_repos': 22,
#  'public_gists': 0,
#  'followers': 1,
#  'following': 8,
#  'created_at': '2020-01-29T01:58:41Z',
#  'updated_at': '2024-01-22T22:10:00Z'}

# %% [markdown]
# From the json output above, I'll try to extract basic information such as `name`, `location`, `email`, `bio`, `public_repos`, and `public gists`. I'll also keep some of the urls handy inluding `repos_url`, `gists_url` and `blog`.

# %%
print("Information about user {}:\n".format(credentials['username']))
print("Name: {}".format(data['name']))
print("Email: {}".format(data['email']))
print("Location: {}".format(data['location']))
print("Public repos: {}".format(data['public_repos']))
print("Public gists: {}".format(data['public_gists']))
print("About: {}".format(data['bio']))
# Out:
# Information about user BandhaviC:
#
# Name: Bandhavi Chitturi
# Email: None
# Location: Smyrna, GA
# Public repos: 22
# Public gists: 0
# About: I'm a passionate Data enthusiast! I have experience as a Data Analyst. I like to bring insights from data that helps in predictions and recommendation systems.

# %% [markdown]
# ## Repositories
#
# Next, I'll fetch repositories for the user. By default, only 30 repositories are fetched in one go. So, I'll iterate over the API till all repositories are fetched.

# %%
url = data['repos_url']
page_no = 1
repos_data = []
while (True):
    response = requests.get(url, auth = authentication)
    response = response.json()
    repos_data = repos_data + response
    repos_fetched = len(response)
    print("Total repositories fetched: {}".format(repos_fetched))
    if (repos_fetched == 30):
        page_no = page_no + 1
        url = data['repos_url'].encode("UTF-8") + '?page=' + str(page_no)
    else:
        break
# Out:
# Total repositories fetched: 22

# %% [markdown]
# I'll first explore only one repository information and take a look at all the information I can keep.

# %%
repos_data[0]
# Out:
# {'id': 746834741,
#  'node_id': 'R_kgDOLIPLNQ',
#  'name': '911_Calls_Data_Analysis',
#  'full_name': 'BandhaviC/911_Calls_Data_Analysis',
#  'private': False,
#  'owner': {'login': 'BandhaviC',
#   'id': 60414933,
#   'node_id': 'MDQ6VXNlcjYwNDE0OTMz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/60414933?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/BandhaviC',
#   'html_url': 'https://github.com/BandhaviC',
#   'followers_url': 'https://api.github.com/users/BandhaviC/followers',
#   'following_url': 'https://api.github.com/users/BandhaviC/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/BandhaviC/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/BandhaviC/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/BandhaviC/subscriptions',
#   'organizations_url': 'https://api.github.com/users/BandhaviC/orgs',
#   'repos_url': 'https://api.github.com/users/BandhaviC/repos',
#   'events_url': 'https://api.github.com/users/BandhaviC/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/BandhaviC/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/BandhaviC/911_Calls_Data_Analysis',
#  'description': 'This is a data capstone project of 911 Calls Data. I have done elaborate data analysis and visualization of the dataset.',
#  'fork': False,
#  'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis',
#  'forks_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/forks',
#  'keys_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/teams',
#  'hooks_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/hooks',
#  'issue_events_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/events',
#  'assignees_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/tags',
#  'blobs_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/languages',
#  'stargazers_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/stargazers',
#  'contributors_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/contributors',
#  'subscribers_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/subscribers',
#  'subscription_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/subscription',
#  'commits_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/merges',
#  'archive_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/downloads',
#  'issues_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/deployments',
#  'created_at': '2024-01-22T19:07:47Z',
#  'updated_at': '2024-01-22T22:12:14Z',
#  'pushed_at': '2024-01-22T22:06:28Z',
#  'git_url': 'git://github.com/BandhaviC/911_Calls_Data_Analysis.git',
#  'ssh_url': 'git@github.com:BandhaviC/911_Calls_Data_Analysis.git',
#  'clone_url': 'https://github.com/BandhaviC/911_Calls_Data_Analysis.git',
#  'svn_url': 'https://github.com/BandhaviC/911_Calls_Data_Analysis',
#  'homepage': '',
#  'size': 5055,
#  'stargazers_count': 0,
#  'watchers_count': 0,
#  'language': 'Jupyter Notebook',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'has_discussions': False,
#  'forks_count': 0,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 0,
#  'license': None,
#  'allow_forking': True,
#  'is_template': False,
#  'web_commit_signoff_required': False,
#  'topics': ['exploratory-data-analysis', 'python', 'visualizations'],
#  'visibility': 'public',
#  'forks': 0,
#  'open_issues': 0,
#  'watchers': 0,
#  'default_branch': 'main'}

# %% [markdown]
# There are a number of things that we can keep a track of here. I'll select the following:
# 1. id: Unique id for the repository.
# 2. name: The name of the repository.
# 3. description: The description of the repository.
# 4. created_at: The time and date when the repository was first created.
# 5. updated_at: The time and date when the repository was last updated.
# 6. login: Username of the owner of the repository.
# 7. license: The license type (if any).
# 8. has_wiki: A boolean that signifies if the repository has a wiki document.
# 9. forks_count: Total forks of the repository.
# 10. open_issues_count: Total issues opened in the repository.
# 11. stargazers_count: The total stars on the reepository.
# 12. watchers_count: Total users watching the repository.

# %% [markdown]
# I'll also keep track of some urls for further analysis including:
# 1. url: The url of the repository.
# 2. commits_url: The url for all commits in the repository.
# 3. languages_url: The url for all languages in the repository.
#
# The commit url, I'll remove the end value inside the braces.

# %%
repos_information = []
for i, repo in enumerate(repos_data):
    data = []
    data.append(repo['id'])
    data.append(repo['name'])
    data.append(repo['description'])
    data.append(repo['created_at'])
    data.append(repo['updated_at'])
    data.append(repo['owner']['login'])
    data.append(repo['license']['name'] if repo['license'] != None else None)
    data.append(repo['has_wiki'])
    data.append(repo['forks_count'])
    data.append(repo['open_issues_count'])
    data.append(repo['stargazers_count'])
    data.append(repo['watchers_count'])
    data.append(repo['url'])
    data.append(repo['commits_url'].split("{")[0])
    data.append(repo['url'] + '/languages')
    repos_information.append(data)

# %%
repos_df = pd.DataFrame(repos_information, columns = ['Id', 'Name', 'Description', 'Created on', 'Updated on', 
                                                      'Owner', 'License', 'Includes wiki', 'Forks count', 
                                                      'Issues count', 'Stars count', 'Watchers count',
                                                      'Repo URL', 'Commits URL', 'Languages URL'])
repos_df.head(10)
# Out:
#           Id                                   Name  \
# 0  746834741                911_Calls_Data_Analysis
# 1  702736151  Apache-Beam-Batch-processing_Dataflow
# 2  741108129                    BandhaviC.github.io
# 3  360756417                               Beachbnb
# 4  702722284   Customer-Segmentation-and-Clustering
# 5  632156401   DataStructures_and_algorithms_Python
# 6  657332813              Data_Analysis_of_UberData
# 7  639551572  data_engineering_with_snowpark_python
# 8  619930653                        Data_Science-ML
# 9  742164526               E-commerce-Data-Analysis
#
#                                          Description            Created on  \
# 0  This is a data capstone project of 911 Calls D...  2024-01-22T19:07:47Z
# 1                                               None  2023-10-09T23:00:51Z
# 2                                               None  2024-01-09T17:58:59Z
# 3                                               None  2021-04-23T03:52:14Z
# 4                                               None  2023-10-09T22:00:28Z
# 5                                               None  2023-04-24T20:37:49Z
# 6                                               None  2023-06-22T20:43:43Z
# 7                                               None  2023-05-11T17:35:31Z
# 8                                               None  2023-03-27T17:38:38Z
# 9                                               None  2024-01-11T22:16:09Z
#
#              Updated on      Owner                          License  \
# 0  2024-01-22T22:12:14Z  BandhaviC                             None
# 1  2023-10-09T23:01:56Z  BandhaviC                      MIT License
# 2  2024-01-10T20:30:36Z  BandhaviC                             None
# 3  2021-04-23T04:01:32Z  BandhaviC                             None
# 4  2023-10-09T22:00:33Z  BandhaviC                             None
# 5  2023-06-21T20:47:23Z  BandhaviC                             None
# 6  2023-06-22T20:43:50Z  BandhaviC  GNU General Public License v3.0
# 7  2023-05-11T17:40:38Z  BandhaviC               Apache License 2.0
# 8  2023-03-27T17:41:09Z  BandhaviC                             None
# 9  2024-01-11T22:16:19Z  BandhaviC                             None
#
#    Includes wiki  Forks count  Issues count  Stars count  Watchers count  \
# 0           True            0             0            0               0
# 1           True            0             0            0               0
# 2          False            0             0            1               1
# 3           True            0             0            0               0
# 4           True            0             0            0               0
# 5          False            0             0            0               0
# 6           True            0             0            0               0
# 7           True            0             0            0               0
# 8           True            0             0            0               0
# 9           True            0             0            0               0
#
#                                             Repo URL  \
# 0  https://api.github.com/repos/BandhaviC/911_Cal...
# 1  https://api.github.com/repos/BandhaviC/Apache-...
# 2  https://api.github.com/repos/BandhaviC/Bandhav...
# 3    https://api.github.com/repos/BandhaviC/Beachbnb
# 4  https://api.github.com/repos/BandhaviC/Custome...
# 5  https://api.github.com/repos/BandhaviC/DataStr...
# 6  https://api.github.com/repos/BandhaviC/Data_An...
# 7  https://api.github.com/repos/BandhaviC/data_en...
# 8  https://api.github.com/repos/BandhaviC/Data_Sc...
# 9  https://api.github.com/repos/BandhaviC/E-comme...
#
#                                          Commits URL  \
# 0  https://api.github.com/repos/BandhaviC/911_Cal...
# 1  https://api.github.com/repos/BandhaviC/Apache-...
# 2  https://api.github.com/repos/BandhaviC/Bandhav...
# 3  https://api.github.com/repos/BandhaviC/Beachbn...
# 4  https://api.github.com/repos/BandhaviC/Custome...
# 5  https://api.github.com/repos/BandhaviC/DataStr...
# 6  https://api.github.com/repos/BandhaviC/Data_An...
# 7  https://api.github.com/repos/BandhaviC/data_en...
# 8  https://api.github.com/repos/BandhaviC/Data_Sc...
# 9  https://api.github.com/repos/BandhaviC/E-comme...
#
#                                        Languages URL
# 0  https://api.github.com/repos/BandhaviC/911_Cal...
# 1  https://api.github.com/repos/BandhaviC/Apache-...
# 2  https://api.github.com/repos/BandhaviC/Bandhav...
# 3  https://api.github.com/repos/BandhaviC/Beachbn...
# 4  https://api.github.com/repos/BandhaviC/Custome...
# 5  https://api.github.com/repos/BandhaviC/DataStr...
# 6  https://api.github.com/repos/BandhaviC/Data_An...
# 7  https://api.github.com/repos/BandhaviC/data_en...
# 8  https://api.github.com/repos/BandhaviC/Data_Sc...
# 9  https://api.github.com/repos/BandhaviC/E-comme...

# %% [markdown]
# ## Languages
#
# For topics of each repository, I'll iterate through all repos' `Languagues URL` and get the corresponding data. I'll also store them back to the dataframe.

# %%
for i in range(repos_df.shape[0]):
    response = requests.get(repos_df.loc[i, 'Languages URL'], auth = authentication)
    response = response.json()
    print(i, response)
    if response != {}:
        languages = []
        for key, value in response.items():
            languages.append(key)
        languages = ', '.join(languages)
        repos_df.loc[i, 'Languages'] = languages
    else:
        repos_df.loc[i, 'Languages'] = ""
# Out:
# 0 {'Jupyter Notebook': 506555}
# 1 {'Python': 1927}
# 2 {'JavaScript': 99440, 'HTML': 1733, 'CSS': 735}
# 3 {'TypeScript': 36262, 'HTML': 11684, 'SCSS': 8767, 'JavaScript': 1851}
# 4 {'Jupyter Notebook': 654912}
# 5 {'Jupyter Notebook': 31817, 'Python': 1284}
# 6 {'Jupyter Notebook': 202855}
# 7 {'Python': 26583, 'PLpgSQL': 2274}
# 8 {'Jupyter Notebook': 40628506, 'HTML': 6312735}
# 9 {'Jupyter Notebook': 3971306}
# 10 {'Jupyter Notebook': 184261, 'Python': 52495}
# 11 {'Jupyter Notebook': 87096}
# 12 {'CSS': 85076, 'SCSS': 77989, 'HTML': 39074, 'JavaScript': 17779}
# 13 {'TypeScript': 25928, 'HTML': 12471, 'JavaScript': 4614, 'CSS': 196}
# 14 {'JavaScript': 7976, 'HTML': 1721, 'CSS': 1240}
# 15 {'Python': 1019}
# 16 {'JavaScript': 11401, 'CSS': 10251, 'HTML': 361}
# 17 {'TypeScript': 49005, 'HTML': 21949, 'SCSS': 4612, 'JavaScript': 2325}
# 18 {'Jupyter Notebook': 255488}
# 19 {'Jupyter Notebook': 654653}
# 20 {'JavaScript': 7843, 'CSS': 713, 'HTML': 400}
# 21 {'Python': 4099}

# %% [markdown]
# I'll publish this data into a .csv file called **repos_info.csv**

# %%
repos_df.to_csv('repos_info.csv', index = False)

# %% [markdown]
# ## Commits
#
# I'll now also create a dataset with all the commits done till now.

# %%
response = requests.get(repos_df.loc[0, 'Commits URL'], auth = authentication)
response.json()
# Out:
# [{'sha': '68a0d7ce20251e6e1e9c72062bd22d25e9aa17e3',
#   'node_id': 'C_kwDOLIPLNdoAKDY4YTBkN2NlMjAyNTFlNmUxZTljNzIwNjJiZDIyZDI1ZTlhYTE3ZTM',
#   'commit': {'author': {'name': 'Bandhavi Chitturi',
#     'email': '60414933+BandhaviC@users.noreply.github.com',
#     'date': '2024-01-22T22:06:28Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-01-22T22:06:28Z'},
#    'message': 'Update README.md',
#    'tree': {'sha': '7fc7fb048d5667df187b0abd8906032f489af964',
#     'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/trees/7fc7fb048d5667df187b0abd8906032f489af964'},
#    'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/commits/68a0d7ce20251e6e1e9c72062bd22d25e9aa17e3',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\ntrR7NPX4nbapnKVxwe8Y\n=fWKX\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 7fc7fb048d5667df187b0abd8906032f489af964\nparent f2230fc11583c9ac61384434ddb3feb6ae1e701d\nauthor Bandhavi Chitturi <60414933+BandhaviC@users.noreply.github.com> 1705961188 -0500\ncommitter GitHub <noreply@github.com> 1705961188 -0500\n\nUpdate README.md'}},
#   'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits/68a0d7ce20251e6e1e9c72062bd22d25e9aa17e3',
#   'html_url': 'https://github.com/BandhaviC/911_Calls_Data_Analysis/commit/68a0d7ce20251e6e1e9c72062bd22d25e9aa17e3',
#   'comments_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits/68a0d7ce20251e6e1e9c72062bd22d25e9aa17e3/comments',
#   'author': {'login': 'BandhaviC',
#    'id': 60414933,
#    'node_id': 'MDQ6VXNlcjYwNDE0OTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60414933?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BandhaviC',
#    'html_url': 'https://github.com/BandhaviC',
#    'followers_url': 'https://api.github.com/users/BandhaviC/followers',
#    'following_url': 'https://api.github.com/users/BandhaviC/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/BandhaviC/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/BandhaviC/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/BandhaviC/subscriptions',
#    'organizations_url': 'https://api.github.com/users/BandhaviC/orgs',
#    'repos_url': 'https://api.github.com/users/BandhaviC/repos',
#    'events_url': 'https://api.github.com/users/BandhaviC/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/BandhaviC/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'f2230fc11583c9ac61384434ddb3feb6ae1e701d',
#     'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits/f2230fc11583c9ac61384434ddb3feb6ae1e701d',
#     'html_url': 'https://github.com/BandhaviC/911_Calls_Data_Analysis/commit/f2230fc11583c9ac61384434ddb3feb6ae1e701d'}]},
#  {'sha': 'f2230fc11583c9ac61384434ddb3feb6ae1e701d',
#   'node_id': 'C_kwDOLIPLNdoAKGYyMjMwZmMxMTU4M2M5YWM2MTM4NDQzNGRkYjNmZWI2YWUxZTcwMWQ',
#   'commit': {'author': {'name': 'Bandhavi Chitturi',
#     'email': '60414933+BandhaviC@users.noreply.github.com',
#     'date': '2024-01-22T22:06:10Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-01-22T22:06:10Z'},
#    'message': 'Create README.md',
#    'tree': {'sha': 'c7112931cba9ba30c507e963bab9afc10a9b7848',
#     'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/trees/c7112931cba9ba30c507e963bab9afc10a9b7848'},
#    'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/commits/f2230fc11583c9ac61384434ddb3feb6ae1e701d',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\ndI86wFTpyQrvHPQVkGKX\n=lTfY\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree c7112931cba9ba30c507e963bab9afc10a9b7848\nparent fb33a7dc044411c6740debdb3fc2859c19527f83\nauthor Bandhavi Chitturi <60414933+BandhaviC@users.noreply.github.com> 1705961170 -0500\ncommitter GitHub <noreply@github.com> 1705961170 -0500\n\nCreate README.md'}},
#   'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits/f2230fc11583c9ac61384434ddb3feb6ae1e701d',
#   'html_url': 'https://github.com/BandhaviC/911_Calls_Data_Analysis/commit/f2230fc11583c9ac61384434ddb3feb6ae1e701d',
#   'comments_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits/f2230fc11583c9ac61384434ddb3feb6ae1e701d/comments',
#   'author': {'login': 'BandhaviC',
#    'id': 60414933,
#    'node_id': 'MDQ6VXNlcjYwNDE0OTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60414933?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BandhaviC',
#    'html_url': 'https://github.com/BandhaviC',
#    'followers_url': 'https://api.github.com/users/BandhaviC/followers',
#    'following_url': 'https://api.github.com/users/BandhaviC/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/BandhaviC/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/BandhaviC/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/BandhaviC/subscriptions',
#    'organizations_url': 'https://api.github.com/users/BandhaviC/orgs',
#    'repos_url': 'https://api.github.com/users/BandhaviC/repos',
#    'events_url': 'https://api.github.com/users/BandhaviC/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/BandhaviC/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'fb33a7dc044411c6740debdb3fc2859c19527f83',
#     'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits/fb33a7dc044411c6740debdb3fc2859c19527f83',
#     'html_url': 'https://github.com/BandhaviC/911_Calls_Data_Analysis/commit/fb33a7dc044411c6740debdb3fc2859c19527f83'}]},
#  {'sha': 'fb33a7dc044411c6740debdb3fc2859c19527f83',
#   'node_id': 'C_kwDOLIPLNdoAKGZiMzNhN2RjMDQ0NDExYzY3NDBkZWJkYjNmYzI4NTljMTk1MjdmODM',
#   'commit': {'author': {'name': 'Bandhavi Chitturi',
#     'email': '60414933+BandhaviC@users.noreply.github.com',
#     'date': '2024-01-22T22:04:21Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-01-22T22:04:21Z'},
#    'message': '911 calls analysis EDA',
#    'tree': {'sha': '5aada22d430c914164d6d5c7ce07e0622c628973',
#     'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/trees/5aada22d430c914164d6d5c7ce07e0622c628973'},
#    'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/git/commits/fb33a7dc044411c6740debdb3fc2859c19527f83',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nw6dsyJJy5psUBAe2K3b9\n=N7XF\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 5aada22d430c914164d6d5c7ce07e0622c628973\nauthor Bandhavi Chitturi <60414933+BandhaviC@users.noreply.github.com> 1705961061 -0500\ncommitter GitHub <noreply@github.com> 1705961061 -0500\n\n911 calls analysis EDA'}},
#   'url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits/fb33a7dc044411c6740debdb3fc2859c19527f83',
#   'html_url': 'https://github.com/BandhaviC/911_Calls_Data_Analysis/commit/fb33a7dc044411c6740debdb3fc2859c19527f83',
#   'comments_url': 'https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits/fb33a7dc044411c6740debdb3fc2859c19527f83/comments',
#   'author': {'login': 'BandhaviC',
#    'id': 60414933,
#    'node_id': 'MDQ6VXNlcjYwNDE0OTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60414933?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BandhaviC',
#    'html_url': 'https://github.com/BandhaviC',
#    'followers_url': 'https://api.github.com/users/BandhaviC/followers',
#    'following_url': 'https://api.github.com/users/BandhaviC/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/BandhaviC/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/BandhaviC/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/BandhaviC/subscriptions',
#    'organizations_url': 'https://api.github.com/users/BandhaviC/orgs',
#    'repos_url': 'https://api.github.com/users/BandhaviC/repos',
#    'events_url': 'https://api.github.com/users/BandhaviC/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/BandhaviC/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': []}]

# %% [markdown]
# I'll save the id, date and the message of each commit.

# %%
commits_information = []
for i in range(repos_df.shape[0]):
    url = repos_df.loc[i, 'Commits URL']
    page_no = 1
    while (True):
        response = requests.get(url, auth = authentication)
        response = response.json()
        print("URL: {}, commits: {}".format(url, len(response)))
        for commit in response:
            commit_data = []
            commit_data.append(repos_df.loc[i, 'Id'])
            commit_data.append(commit['sha'])
            commit_data.append(commit['commit']['committer']['date'])
            commit_data.append(commit['commit']['message'])
            commits_information.append(commit_data)
        if (len(response) == 30):
            page_no = page_no + 1
            url = repos_df.loc[i, 'Commits URL'] + '?page=' + str(page_no)
        else:
            break
# Out:
# URL: https://api.github.com/repos/BandhaviC/911_Calls_Data_Analysis/commits, commits: 3
# URL: https://api.github.com/repos/BandhaviC/Apache-Beam-Batch-processing_Dataflow/commits, commits: 3
# URL: https://api.github.com/repos/BandhaviC/BandhaviC.github.io/commits, commits: 3
# URL: https://api.github.com/repos/BandhaviC/Beachbnb/commits, commits: 2
# URL: https://api.github.com/repos/BandhaviC/Customer-Segmentation-and-Clustering/commits, commits: 4
# URL: https://api.github.com/repos/BandhaviC/DataStructures_and_algorithms_Python/commits, commits: 20
# URL: https://api.github.com/repos/BandhaviC/Data_Analysis_of_UberData/commits, commits: 6
# URL: https://api.github.com/repos/BandhaviC/data_engineering_with_snowpark_python/commits, commits: 16
# URL: https://api.github.com/repos/BandhaviC/Data_Science-ML/commits, commits: 3
# URL: https://api.github.com/repos/BandhaviC/E-commerce-Data-Analysis/commits, commits: 1
# URL: https://api.github.com/repos/BandhaviC/Google-Cloud-Analytics/commits, commits: 1
# URL: https://api.github.com/repos/BandhaviC/K-Means_Clustering/commits, commits: 9
# URL: https://api.github.com/repos/BandhaviC/myportfolio/commits, commits: 30
# URL: https://api.github.com/repos/BandhaviC/myportfolio/commits?page=2, commits: 11
# URL: https://api.github.com/repos/BandhaviC/onlinestore/commits, commits: 4
# URL: https://api.github.com/repos/BandhaviC/Photojournal/commits, commits: 4
# URL: https://api.github.com/repos/BandhaviC/Pytest-ETLPipelines/commits, commits: 6
# URL: https://api.github.com/repos/BandhaviC/react-portfolio/commits, commits: 13
# URL: https://api.github.com/repos/BandhaviC/SmartCare/commits, commits: 8
# URL: https://api.github.com/repos/BandhaviC/Spotify-Top-100-Songs-Analysis/commits, commits: 3
# URL: https://api.github.com/repos/BandhaviC/Telecom_Customer_Churn_Prediction/commits, commits: 5
# URL: https://api.github.com/repos/BandhaviC/Todo-App-ReduxToolkit_latest/commits, commits: 3
# URL: https://api.github.com/repos/BandhaviC/Unit_testing_python/commits, commits: 4

# %%
commits_df = pd.DataFrame(commits_information, columns = ['Repo Id', 'Commit Id', 'Date', 'Message'])
commits_df.head(5)
# Out:
#      Repo Id                                 Commit Id                  Date  \
# 0  746834741  68a0d7ce20251e6e1e9c72062bd22d25e9aa17e3  2024-01-22T22:06:28Z
# 1  746834741  f2230fc11583c9ac61384434ddb3feb6ae1e701d  2024-01-22T22:06:10Z
# 2  746834741  fb33a7dc044411c6740debdb3fc2859c19527f83  2024-01-22T22:04:21Z
# 3  702736151  d4b70f999620be3c1deb9ae690131f032973634b  2023-10-09T23:04:28Z
# 4  702736151  acac3958bf93947b7588dd28eccdd6dac46fad93  2023-10-09T23:03:39Z
#
#                   Message
# 0        Update README.md
# 1        Create README.md
# 2  911 calls analysis EDA
# 3        Update README.md
# 4        Update README.md

# %% [markdown]
# I'll publish this data into a .csv file called **commits_info.csv**

# %%
commits_df.to_csv('commits_info.csv', index = False)
